# %% [markdown]
# # TCGA-PRAD Survival Prediction - VERSION 1 Exploration
# ## Exploratory Data Analysis and Model Development

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')

from preprocessing import load_csv, clean_data, merge_datasets, scale_features
from model import train_logistic_regression, predict
from evaluation import compute_auc, plot_roc
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Load and Explore Data

# %%
# Load datasets
clinical_df = load_csv('../data/TCGA-PRAD.clinical.tsv')
survival_df = load_csv('../data/TCGA-PRAD.survival.tsv')
protein_df = load_csv('../data/TCGA-PRAD.protein.tsv')
